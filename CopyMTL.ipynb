# %%
cd drive/Othercomputers/My\ MacBook\ Pro/G\ drive/stevens\ sem\ 2/Artifical/project/CopyMTL-master
# Out:
# /content/drive/Othercomputers/My MacBook Pro/G drive/stevens sem 2/Artifical/project/CopyMTL-master

# %%
# !pip install torch==1.8.1
# Out:
# ...
#      |████████████████████████████████| 804.1 MB 2.4 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.12.0+cu113 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.8.1 which is incompatible.
# ...

# %%
# !python main.py --gpu 0 --mode train --cell lstm --decoder_type one
# Out:
# config filename: ./config.json
# load_embedding!
# loading ./data/nyt/seq2seq_re/train.json
# data size 56195
# /content/drive/Othercomputers/My MacBook Pro/G drive/stevens sem 2/Artifical/project/CopyMTL-master/data_prepare.py:32: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.all_triples_id = np.asanyarray(all_triples_id)  # gold triples without padding
# loading ./data/nyt/seq2seq_re/test.json
# data size 5000
# ____________________________________________________________
# epoch 1 	 loss: 5.443198 	 F1: 0.491840 	 P: 0.569321 	 R: 0.432922
# relation 	 F1: 0.724802 	 P: 0.838982 	 R: 0.637978
# entity 	 F1: 0.575751 	 P: 0.666450 	 R: 0.506782
# ____________________________________________________________
# ...

# %%
 # !python main.py --gpu 0 --mode test --cell lstm --decoder_type one

# %%
# !python main.py --gpu 0 --mode train --cell lstm --decoder_type one
# Out:
# config filename: ./config.json
# load_embedding!
# loading ./data/webnlg/entity_end_position/train.json
# data size 5019
# /content/drive/Othercomputers/My MacBook Pro/G drive/stevens sem 2/Artifical/project/CopyMTL-master/data_prepare.py:32: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.all_triples_id = np.asanyarray(all_triples_id)  # gold triples without padding
# loading ./data/webnlg/entity_end_position/dev.json
# data size 703
# ____________________________________________________________
# epoch 1 	 loss: 18.911304 	 F1: 0.000775 	 P: 0.000986 	 R: 0.000639
# relation 	 F1: 0.148895 	 P: 0.189349 	 R: 0.122684
# entity 	 F1: 0.059713 	 P: 0.075937 	 R: 0.049201
# ____________________________________________________________
# ...

# %%
# !python main.py --gpu 0 --mode test --cell lstm --decoder_type one
# Out:
# config filename: ./config.json
# loading ./data/webnlg/entity_end_position/dev.json
# data size 703
# /content/drive/Othercomputers/My MacBook Pro/G drive/stevens sem 2/Artifical/project/CopyMTL-master/data_prepare.py:32: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self.all_triples_id = np.asanyarray(all_triples_id)  # gold triples without padding
# triplet 	 F1: 0.566013 	 P: 0.579264 	 R: 0.553355
